# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect(r"C:\Users\my pc\Desktop\sales.db")

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('sales',)]

# %%
query = "SELECT * FROM sales LIMIT 5;"
df = pd.read_sql_query(query, conn)
df
# Out:
#            field1     field2         field3           field4      field5  \
# 0       Ship Mode    Segment        Country             City       State
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class   Consumer  United States        Henderson    Kentucky
# 3    Second Class  Corporate  United States      Los Angeles  California
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#         field6  field7           field8        field9   field10   field11  \
# 0  Postal Code  Region         Category  Sub-Category     Sales  Quantity
# 1        42420   South        Furniture     Bookcases    261.96         2
# 2        42420   South        Furniture        Chairs    731.94         3
# 3        90036    West  Office Supplies        Labels     14.62         2
# 4        33311   South        Furniture        Tables  957.5775         5
#
#     field12   field13
# 0  Discount    Profit
# 1         0   41.9136
# ...

# %%
query = "SELECT field8, field10 FROM sales LIMIT 10;"
df = pd.read_sql_query(query, conn)
df
# Out:
#             field8   field10
# 0         Category     Sales
# 1        Furniture    261.96
# 2        Furniture    731.94
# 3  Office Supplies     14.62
# 4        Furniture  957.5775
# 5  Office Supplies    22.368
# 6        Furniture     48.86
# 7  Office Supplies      7.28
# 8       Technology   907.152
# 9  Office Supplies    18.504

# %%
query = "SELECT * FROM sales WHERE field10 > 1000;"
df = pd.read_sql_query(query, conn)
df
# Out:
#               field1     field2         field3           field4      field5  \
# 0          Ship Mode    Segment        Country             City       State
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class   Consumer  United States        Henderson    Kentucky
# 3       Second Class  Corporate  United States      Los Angeles  California
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9722    Second Class   Consumer  United States            Miami     Florida
# 9723  Standard Class   Consumer  United States       Costa Mesa  California
# 9724  Standard Class   Consumer  United States       Costa Mesa  California
# 9725  Standard Class   Consumer  United States       Costa Mesa  California
# 9726    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
query = "SELECT * FROM sales ORDER BY field10 DESC;"
df = pd.read_sql_query(query, conn)
df
# Out:
#               field1       field2         field3        field4        field5  \
# 0          Ship Mode      Segment        Country          City         State
# 1       Second Class  Home Office  United States  Indianapolis       Indiana
# 2     Standard Class     Consumer  United States    Des Moines    Washington
# 3       Second Class  Home Office  United States     Milwaukee     Wisconsin
# 4     Standard Class     Consumer  United States     Arlington         Texas
# ...              ...          ...            ...           ...           ...
# 9990        Same Day    Corporate  United States      Mesquite         Texas
# 9991        Same Day     Consumer  United States  Philadelphia  Pennsylvania
# 9992  Standard Class    Corporate  United States       Chicago      Illinois
# 9993        Same Day    Corporate  United States          Waco         Texas
# 9994  Standard Class     Consumer  United States       Houston         Texas
#
# ...

# %%
query = "SELECT AVG(field10) AS Average_Sales FROM sales;"
df = pd.read_sql_query(query, conn)
df
# Out:
#    Average_Sales
# 0     229.835004

# %%
query = "SELECT AVG(field10) AS Average_Sales FROM sales;"
df = pd.read_sql_query(query, conn)
df
# Out:
#    Average_Sales
# 0     229.835004

# %%
conn.close()
